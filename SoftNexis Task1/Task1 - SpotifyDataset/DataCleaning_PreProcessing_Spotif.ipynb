# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
spotify_data = pd.read_csv('./Spotify+Streaming+History/spotify_history.csv')
print(spotify_data.head().to_string())
print("\n")
print(spotify_data.info())
print("\n")
print(spotify_data.shape)
# Out:
#         spotify_track_uri                   ts    platform  ms_played                                     track_name        artist_name                          album_name reason_start reason_end  shuffle  skipped
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow    False    False
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow    False    False
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown    False    False
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow    False    False
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn    False    False
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149860 entries, 0 to 149859
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   spotify_track_uri  149860 non-null  object
#  1   ts                 149860 non-null  object
#  2   platform           149860 non-null  object
#  3   ms_played          149860 non-null  int64
#  4   track_name         149860 non-null  object
#  5   artist_name        149860 non-null  object
#  6   album_name         149860 non-null  object
#  7   reason_start       149717 non-null  object
#  8   reason_end         149743 non-null  object
#  9   shuffle            149860 non-null  bool
#  10  skipped            149860 non-null  bool
# dtypes: bool(2), int64(1), object(8)
# memory usage: 10.6+ MB
# None
#
#
# (149860, 11)

# %%
DuplicateRowsum = spotify_data.duplicated().sum()
print("Number of duplicated rows: ",DuplicateRowsum )
print("The Duplicated Rows are: \n", spotify_data[spotify_data.duplicated()])
print("\n")
database_withDuplicatedRowsGone = spotify_data.drop_duplicates()
print("The Database Without the Duplicaed Rows Here \n ", database_withDuplicatedRowsGone.head().to_string())
print("\n")
# Out:
# Number of duplicated rows:  1185
# The Duplicated Rows are:
#               spotify_track_uri                   ts platform  ms_played  \
# 1684    3GGUWP38wpqwwu5njjjUVx  2015-09-10 03:25:39  android          0
# 4124    6l9EToqnhtadmJ6qX9DDUl  2016-07-17 22:37:14  android     226240
# 4125    4x8KNLPK3PI7sRWBYoOpFQ  2016-07-17 22:37:14  android     165746
# 4126    4kDTvLhGF29gFsqceuxBSC  2016-07-17 22:37:14  android     261080
# 4130    74X1epeRufHckhuX1KFD04  2016-07-17 22:37:14  android     413320
# ...                        ...                  ...      ...        ...
# 122900  1p7m9H4H8s0Y7SgRm7j3ED  2022-08-04 20:20:39  android          0
# 122901  1p7m9H4H8s0Y7SgRm7j3ED  2022-08-04 20:20:39  android          0
# 122904  1p7m9H4H8s0Y7SgRm7j3ED  2022-08-04 20:20:40  android          0
# 125713  4401c08DdNwwGEg8WGCkQf  2022-10-01 23:18:48  android       1611
# 125761  0LxCY6cjKgjutOZaqyjrVQ  2022-10-02 18:34:27  android     221693
#
#                                    track_name      artist_name  \
# 1684                    Je Danse dans ma Tête      Céline Dion
# 4124               Craving - Acoustic Version        James Bay
# 4125    I'm Gonna Find Another You - Acoustic       John Mayer
# 4126                                Not Today  Imagine Dragons
# 4130                               Hallelujah     Jeff Buckley
# ...                                       ...              ...
# 122900                                  Flaca  Andrés Calamaro
# 122901                                  Flaca  Andrés Calamaro
# 122904                                  Flaca  Andrés Calamaro
# 125713     Paperback Writer - Remastered 2009      The Beatles
# 125761                Hombre de ninguna parte       Xoel López
#
#                     album_name reason_start reason_end  shuffle  skipped
# 1684          On ne change pas     clickrow    endplay     True     True
# 4124                   Craving    trackdone  trackdone     True    False
# 4125      The Village Sessions    trackdone  trackdone     True    False
# 4126             Me Before You     clickrow  trackdone    False    False
# 4130    Grace (Legacy Edition)    trackdone  trackdone    False    False
# ...                        ...          ...        ...      ...      ...
# 122900           Alta Suciedad       remote    endplay    False    False
# 122901           Alta Suciedad       remote    endplay    False    False
# 122904           Alta Suciedad       remote    endplay    False    False
# 125713            Past Masters       fwdbtn     fwdbtn     True    False
# 125761               Atlántico       fwdbtn  trackdone     True    False
#
# [1185 rows x 11 columns]
#
#
# The Database Without the Duplicaed Rows Here
#           spotify_track_uri                   ts    platform  ms_played                                     track_name        artist_name                          album_name reason_start reason_end  shuffle  skipped
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow    False    False
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow    False    False
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown    False    False
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow    False    False
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn    False    False

# %%
PartialCopyRowSum = spotify_data.duplicated(subset= spotify_data.columns.difference(['ts']) , keep="first").sum()
print("The No Database's  Partial Duplicates Rows are: ", PartialCopyRowSum)
print("\n")

SpotifyNodupe = spotify_data.drop_duplicates(subset = spotify_data.columns.difference(['ts']) , keep = 'first')
print(SpotifyNodupe.head().to_string())
# Out:
# The No Database's  Partial Duplicates Rows are:  50576
#
#
#         spotify_track_uri                   ts    platform  ms_played                                     track_name        artist_name                          album_name reason_start reason_end  shuffle  skipped
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow    False    False
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow    False    False
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown    False    False
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow    False    False
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn    False    False

# %%
Cross_Columns_spotify = ['track_name', 'artist_name', 'album_name']

paritalDuplicateRows = []

for index, row in spotify_data.iterrows():
    for i in range(len(Cross_Columns_spotify)):
        for j in range(i+1, len(Cross_Columns_spotify)):
            datacal1 = str(row[Cross_Columns_spotify[i]]).lower()
            datacal2 = str(row[Cross_Columns_spotify[j]]).lower()
            if datacal1 and datacal1 != "nan" and datacal1 in datacal2:
                paritalDuplicateRows.append((
                    index,
                    Cross_Columns_spotify[i],
                    Cross_Columns_spotify[j], row[Cross_Columns_spotify[i]],row[Cross_Columns_spotify[j]]
                ))

print("Rows with cross-column redundancy:")
for r in paritalDuplicateRows[:20]:  
    print(r)

if not paritalDuplicateRows:
    print("So We are Observing That there are No cross-column redundancy found in the Spotify dataset.\n")
# Out:
# Rows with cross-column redundancy:
# (2, 'track_name', 'album_name', 'Born To Die', 'Born To Die - The Paradise Edition')
# (5, 'track_name', 'album_name', 'Impossible', 'Impossible')
# (8, 'track_name', 'album_name', 'Happy Up Here', 'Happy Up Here')
# (9, 'track_name', 'album_name', 'Phantom', 'Phantom')
# (13, 'track_name', 'album_name', 'Do I Wanna Know?', 'Do I Wanna Know?')
# (22, 'track_name', 'album_name', 'Paper Doll', 'Paper Doll')
# (23, 'track_name', 'album_name', '7th Street', '7th Street')
# (26, 'track_name', 'album_name', 'Say', 'Say')
# (27, 'track_name', 'album_name', 'Waiting On the World to Change', 'Waiting On The World To Change')
# (29, 'track_name', 'album_name', 'Daughters', 'Daughters')
# (31, 'artist_name', 'album_name', 'John Mayer', 'Where the Light Is: John Mayer Live In Los Angeles')
# (32, 'track_name', 'album_name', 'Paper Doll', 'Paper Doll')
# (38, 'artist_name', 'album_name', 'John Mayer', 'Where the Light Is: John Mayer Live In Los Angeles')
# (40, 'artist_name', 'album_name', 'John Mayer', 'Where the Light Is: John Mayer Live In Los Angeles')
# (43, 'track_name', 'album_name', 'Young And Beautiful', 'Young And Beautiful')
# (44, 'track_name', 'album_name', 'Young And Beautiful', 'Young And Beautiful')
# (45, 'track_name', 'album_name', 'Young And Beautiful', 'Young And Beautiful')
# (64, 'track_name', 'album_name', 'Paper Doll', 'Paper Doll')
# (72, 'artist_name', 'album_name', 'U2', 'U218 Singles')
# (74, 'artist_name', 'album_name', 'U2', 'U218 Singles')

# %%
# Rename columns

print(spotify_data.info())


New_Spotify_Instruction = {

 "spotify_track_uri": "Spoftify_track_uri",
    "ts": "Spotify_TimeStamp",               
    "platform": "StreamingPlatform",          
    "ms_played": "Play_Duration_ms", 
    "track_name": "Track's_Name",
    "artist_name": "Artist'sNames",
    "album_name": "Album'sTitle",
    "reason_start": "Start_reason",
    "reason_end": "End_reason",
    "shuffle": "Shuffle_On",        
    "skipped": "SkippedOn"  


}


spotify_data = spotify_data.rename(columns=New_Spotify_Instruction)


newspotyorder = [
    "Track's_Name",
    "Artist'sNames",
     "Album'sTitle",
    "Start_reason",
    "End_reason",
    "Spoftify_track_uri",
     "Spotify_TimeStamp",               
     "StreamingPlatform",          
     "Play_Duration_ms", 
     "Shuffle_On",        
     "SkippedOn"  
]

# Reorder columns
spotify_data = spotify_data[newspotyorder]

print(spotify_data.head().to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149860 entries, 0 to 149859
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   spotify_track_uri  149860 non-null  object
#  1   ts                 149860 non-null  object
#  2   platform           149860 non-null  object
#  3   ms_played          149860 non-null  int64
#  4   track_name         149860 non-null  object
#  5   artist_name        149860 non-null  object
#  6   album_name         149860 non-null  object
#  7   reason_start       149717 non-null  object
#  8   reason_end         149743 non-null  object
#  9   shuffle            149860 non-null  bool
#  10  skipped            149860 non-null  bool
# dtypes: bool(2), int64(1), object(8)
# memory usage: 10.6+ MB
# None
#                                     Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri    Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34        web player              3185       False      False
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37        web player             61865       False      False
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24        web player            285386       False      False
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40        web player            134022       False      False
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52        web player                 0       False      False

# %%
print(spotify_data.info())
print(spotify_data.head().to_string())
print("\n")
print("Missing Values in each Column: \n", spotify_data.isnull().sum())
print("\n")
print("Percentage of Missing Values in each Column: \n", (spotify_data.isnull().mean()*100))

Missing_Values_Coloums_Dataframe = pd.DataFrame({
    'Missing_Values_Coloums': spotify_data.isnull().any(),
    'Missing_Values_Count': spotify_data.isnull().sum(),
    'Missing_ValuesIn_Percentage': (spotify_data.isnull().sum() / len(spotify_data)) * 100
})

print(Missing_Values_Coloums_Dataframe.to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149860 entries, 0 to 149859
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Track's_Name        149860 non-null  object
#  1   Artist'sNames       149860 non-null  object
#  2   Album'sTitle        149860 non-null  object
#  3   Start_reason        149717 non-null  object
#  4   End_reason          149743 non-null  object
#  5   Spoftify_track_uri  149860 non-null  object
#  6   Spotify_TimeStamp   149860 non-null  object
#  7   StreamingPlatform   149860 non-null  object
#  8   Play_Duration_ms    149860 non-null  int64
#  9   Shuffle_On          149860 non-null  bool
#  10  SkippedOn           149860 non-null  bool
# dtypes: bool(2), int64(1), object(8)
# memory usage: 10.6+ MB
# None
#                                     Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri    Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34        web player              3185       False      False
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37        web player             61865       False      False
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24        web player            285386       False      False
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40        web player            134022       False      False
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52        web player                 0       False      False
#
#
# Missing Values in each Column:
#  Track's_Name            0
# Artist'sNames           0
# Album'sTitle            0
# Start_reason          143
# End_reason            117
# Spoftify_track_uri      0
# Spotify_TimeStamp       0
# StreamingPlatform       0
# Play_Duration_ms        0
# Shuffle_On              0
# SkippedOn               0
# dtype: int64
#
#
# Percentage of Missing Values in each Column:
#  Track's_Name          0.000000
# Artist'sNames         0.000000
# Album'sTitle          0.000000
# Start_reason          0.095422
# End_reason            0.078073
# Spoftify_track_uri    0.000000
# Spotify_TimeStamp     0.000000
# StreamingPlatform     0.000000
# Play_Duration_ms      0.000000
# Shuffle_On            0.000000
# SkippedOn             0.000000
# dtype: float64
#                     Missing_Values_Coloums  Missing_Values_Count  Missing_ValuesIn_Percentage
# Track's_Name                         False                     0                     0.000000
# Artist'sNames                        False                     0                     0.000000
# Album'sTitle                         False                     0                     0.000000
# Start_reason                          True                   143                     0.095422
# End_reason                            True                   117                     0.078073
# Spoftify_track_uri                   False                     0                     0.000000
# Spotify_TimeStamp                    False                     0                     0.000000
# StreamingPlatform                    False                     0                     0.000000
# Play_Duration_ms                     False                     0                     0.000000
# Shuffle_On                           False                     0                     0.000000
# SkippedOn                            False                     0                     0.000000

# %%
# Deletion: Drop rows/columns if >70% missing

MissingValuePercentage =  spotify_data.isna().mean()
Database_After_DropedColoums = spotify_data.loc[:, MissingValuePercentage <= 0.7]

MissingValuePercentagerow =  spotify_data.isna().mean(axis=1)
Database_After_DropedRows = spotify_data.loc[MissingValuePercentagerow <= 0.7, :]

print("The Database After Dropping the Coloums with more than 70% Missing Values are : \n", Database_After_DropedColoums.head().to_string())
# Out:
# The Database After Dropping the Coloums with more than 70% Missing Values are :
#                                      Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri    Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34        web player              3185       False      False
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37        web player             61865       False      False
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24        web player            285386       False      False
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40        web player            134022       False      False
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52        web player                 0       False      False

# %%
def SpotifyImputation(database):
    for column in database.columns:
        if np.issubdtype(database[column].dtype, np.number):
            median_value = database[column].median()
            database[column].fillna(median_value , inplace=True)
            print(f"Filled NaN in numeric column '{column}' with Median = {median_value}")
        
        elif database[column].dtype == 'object':
            mode_value = database[column].mode()[0]
            database[column].fillna(mode_value , inplace=True)
            print(f"Filled NaN in categorical column '{column}' with Mode = {mode_value}")
        
        elif np.issubdtype(database[column].dtype, np.datetime64):
            database[column] = database[column].interpolate(method='time')
            print(f"Interpolated missing datetime values in '{column}'")
    
    return database
SongDataImputed = SpotifyImputation(spotify_data)
print("The Database After Imputation of Missing Values is : \n", SongDataImputed.head().to_string())
# Out:
# Filled NaN in categorical column 'Track's_Name' with Mode = Ode To The Mets
# Filled NaN in categorical column 'Artist'sNames' with Mode = The Beatles
# Filled NaN in categorical column 'Album'sTitle' with Mode = The Beatles
# Filled NaN in categorical column 'Start_reason' with Mode = trackdone
# Filled NaN in categorical column 'End_reason' with Mode = trackdone
# Filled NaN in categorical column 'Spoftify_track_uri' with Mode = 1BLOVHYYlH4JUHQGcpt75R
# Filled NaN in categorical column 'Spotify_TimeStamp' with Mode = 2018-09-30 21:43:18
# Filled NaN in categorical column 'StreamingPlatform' with Mode = android
# Filled NaN in numeric column 'Play_Duration_ms' with Median = 138840.0
# The Database After Imputation of Missing Values is :
#                                      Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri    Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34        web player              3185       False      False
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37        web player             61865       False      False
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24        web player            285386       False      False
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40        web player            134022       False      False
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52        web player                 0       False      False
# C:\Users\Vijay Pranav\AppData\Local\Temp\ipykernel_33164\3943674780.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   database[column].fillna(mode_value , inplace=True)
# C:\Users\Vijay Pranav\AppData\Local\Temp\ipykernel_33164\3943674780.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   database[column].fillna(median_value , inplace=True)

# %%
#- Diagnose missingness patterns (MCAR, MAR, MNAR)

# %%
#Convert strings to datetime objects (e.g., "2023-12-01" → datetime64)
print(spotify_data.dtypes)
print("\n")

print("Taking Copy of the dataframe for safety purposes\n")
CopyPeopleDataframe = spotify_data.copy()

def StringDateTimeFunc(dataframe, dataframecols):
    for col in dataframecols:
        dataframe[col] = pd.to_datetime(dataframe[col], errors='coerce')
    return dataframe

# use it only on specific columns
CopyPeopleDataframe = StringDateTimeFunc(spotify_data, ["Spotify_TimeStamp"])

print(CopyPeopleDataframe.head().to_string())
print("\n")
print("Generating the Info of the Dataframe After Converting the Spotify_TimeStamp Column to Datetime Format \n")
print(CopyPeopleDataframe.info())
print("\n")
print(spotify_data["Spotify_TimeStamp"].dtype)
# Out:
# Track's_Name                  object
# Artist'sNames                 object
# Album'sTitle                  object
# Start_reason                  object
# End_reason                    object
# Spoftify_track_uri            object
# Spotify_TimeStamp     datetime64[ns]
# StreamingPlatform             object
# Play_Duration_ms               int64
# Shuffle_On                      bool
# SkippedOn                       bool
# dtype: object
#
#
# Taking Copy of the dataframe for safety purposes
#
#                                     Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri   Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34        web player              3185       False      False
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37        web player             61865       False      False
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24        web player            285386       False      False
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40        web player            134022       False      False
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52        web player                 0       False      False
#
#
# Generating the Info of the Dataframe After Converting the Spotify_TimeStamp Column to Datetime Format
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149860 entries, 0 to 149859
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Track's_Name        149860 non-null  object
#  1   Artist'sNames       149860 non-null  object
#  2   Album'sTitle        149860 non-null  object
#  3   Start_reason        149860 non-null  object
#  4   End_reason          149860 non-null  object
#  5   Spoftify_track_uri  149860 non-null  object
#  6   Spotify_TimeStamp   149860 non-null  datetime64[ns]
#  7   StreamingPlatform   149860 non-null  object
#  8   Play_Duration_ms    149860 non-null  int64
#  9   Shuffle_On          149860 non-null  bool
#  10  SkippedOn           149860 non-null  bool
# dtypes: bool(2), datetime64[ns](1), int64(1), object(7)
# memory usage: 10.6+ MB
# None
#
#
# datetime64[ns]

# %%
# Fix numerical columns trapped as strings (e.g., "1,000" → 1000)

print("Taking Copy of the dataframe for safety purposes\n")
CopyPeopleDataframe = spotify_data.copy()
print("Column datatypes before numeric conversion:\n")
print(spotify_data.dtypes)
print("\n")

print(
    "Result: No action needed.\n"
    "Reason → All numeric columns (like 'Play_Duration_ms') are already stored as proper numeric dtypes.\n"
    "Other object columns (e.g., 'Artist'sNames', 'Album'sTitle', 'Start_reason', 'End_reason') "
    "are categorical text fields, not numbers stored as strings. \n"
    "Therefore, applying numeric string conversion would corrupt these columns, "
    "so the step is skipped.\n"
)
print("The Database After Fixing Numerical Columns is : \n", spotify_data.head().to_string())
# Out:
# Taking Copy of the dataframe for safety purposes
#
# Column datatypes before numeric conversion:
#
# Track's_Name                  object
# Artist'sNames                 object
# Album'sTitle                  object
# Start_reason                  object
# End_reason                    object
# Spoftify_track_uri            object
# Spotify_TimeStamp     datetime64[ns]
# StreamingPlatform             object
# Play_Duration_ms               int64
# Shuffle_On                      bool
# SkippedOn                       bool
# dtype: object
#
#
# Result: No action needed.
# Reason → All numeric columns (like 'Play_Duration_ms') are already stored as proper numeric dtypes.
# Other object columns (e.g., 'Artist'sNames', 'Album'sTitle', 'Start_reason', 'End_reason') are categorical text fields, not numbers stored as strings.
# Therefore, applying numeric string conversion would corrupt these columns, so the step is skipped.
#
# The Database After Fixing Numerical Columns is :
#                                      Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri   Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34        web player              3185       False      False
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37        web player             61865       False      False
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24        web player            285386       False      False
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40        web player            134022       False      False
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52        web player                 0       False      False

# %%
#Standardize categorical encoding
categoricalspotify_cols = ["StreamingPlatform", "Start_reason", "End_reason"]
from sklearn.preprocessing import LabelEncoder
def CategoricalEncodeFunc(database, spotifycols):
    spotifysongcont = {}
    for col in spotifycols:
        codecont = LabelEncoder()
        database[col] = database[col].astype(str).str.strip().str.lower()

        
        database[col + "_code"] = codecont.fit_transform(database[col])
        spotifysongcont[col] = codecont

    return database, spotifysongcont

print("Assuming Here the Categorical Columns are : ['StreamingPlatform', 'Start_reason', 'End_reason']\n")
modifieddataframe,spotifysongcont = CategoricalEncodeFunc(spotify_data, categoricalspotify_cols)
print("The Database After Standardization of Categorical Columns is : \n", modifieddataframe.head().to_string())
# Out:
# Assuming Here the Categorical Columns are : ['StreamingPlatform', 'Start_reason', 'End_reason']
#
# The Database After Standardization of Categorical Columns is :
#                                      Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri   Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn  StreamingPlatform_code  Start_reason_code  End_reason_code
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34        web player              3185       False      False                       4                  1                2
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37        web player             61865       False      False                       4                  3                2
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24        web player            285386       False      False                       4                  3               14
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40        web player            134022       False      False                       4                 10                2
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52        web player                 0       False      False                       4                  3                6

# %%
# Normalize text (lowercase, strip whitespace)


def TextNormalizeFunc(database,ordcols):
    for col in ordcols:
        database[col] = database[col].astype(str).str.strip().str.lower()
    return database

songcols = ["Track's_Name", "Artist'sNames", "Album'sTitle",
                "StreamingPlatform", "Start_reason", "End_reason"]

print(f"Assuming Here the Text Columns are : {songcols}\n")
normalizedframe = TextNormalizeFunc(spotify_data,[])
print("The Database After Normalization of Text Columns is : \n", normalizedframe.head().to_string())
# Out:
# Assuming Here the Text Columns are : ["Track's_Name", "Artist'sNames", "Album'sTitle", 'StreamingPlatform', 'Start_reason', 'End_reason']
#
# The Database After Normalization of Text Columns is :
#                                      Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri   Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn  StreamingPlatform_code  Start_reason_code  End_reason_code
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34        web player              3185       False      False                       4                  1                2
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37        web player             61865       False      False                       4                  3                2
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24        web player            285386       False      False                       4                  3               14
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40        web player            134022       False      False                       4                 10                2
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52        web player                 0       False      False                       4                  3                6

# %%
# Fix inconsistent units (e.g., "kg" vs "lbs")

#Map categorical variants (e.g., "M"/"Male" → "Male")

print("\n")
print(spotify_data.head().to_string())
print("\n")
print(spotify_data.info())
print("\n")
print(spotify_data.shape)
print("\n")
print("The Second  & Third One of the  Fix inconsistent units (e.g., kg vs lbs)- Map categorical variants (e.g., M/Male → Male) \n" \
"This is Not UseFull at all for the Given Spotify Dataset As there are No Attributes Depecting gender or Metric Measurements So Not Implemented For this Particular DatasetCode Alone\n")
# Out:
#                                     Track's_Name      Artist'sNames                        Album'sTitle Start_reason End_reason      Spoftify_track_uri   Spotify_TimeStamp StreamingPlatform  Play_Duration_ms  Shuffle_On  SkippedOn  StreamingPlatform_code  Start_reason_code  End_reason_code
# 0                            Say It, Just Say It       The Mowgli's                Waiting For The Dawn     autoplay   clickrow  2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34        web player              3185       False      False                       4                  1                2
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris                           18 Months     clickrow   clickrow  1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37        web player             61865       False      False                       4                  3                2
# 2                                    Born To Die       Lana Del Rey  Born To Die - The Paradise Edition     clickrow    unknown  487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24        web player            285386       False      False                       4                  3               14
# 3                               Off To The Races       Lana Del Rey  Born To Die - The Paradise Edition    trackdone   clickrow  5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40        web player            134022       False      False                       4                 10                2
# 4                                      Half Mast  Empire Of The Sun                  Walking On A Dream     clickrow    nextbtn  0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52        web player                 0       False      False                       4                  3                6
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149860 entries, 0 to 149859
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Track's_Name            149860 non-null  object
#  1   Artist'sNames           149860 non-null  object
#  2   Album'sTitle            149860 non-null  object
#  3   Start_reason            149860 non-null  object
#  4   End_reason              149860 non-null  object
#  5   Spoftify_track_uri      149860 non-null  object
#  6   Spotify_TimeStamp       149860 non-null  datetime64[ns]
#  7   StreamingPlatform       149860 non-null  object
#  8   Play_Duration_ms        149860 non-null  int64
#  9   Shuffle_On              149860 non-null  bool
#  10  SkippedOn               149860 non-null  bool
#  11  StreamingPlatform_code  149860 non-null  int64
#  12  Start_reason_code       149860 non-null  int64
#  13  End_reason_code         149860 non-null  int64
# dtypes: bool(2), datetime64[ns](1), int64(4), object(7)
# memory usage: 14.0+ MB
# None
#
#
# (149860, 14)
#
#
# The Second  & Third One of the  Fix inconsistent units (e.g., kg vs lbs)- Map categorical variants (e.g., M/Male → Male)
# This is Not UseFull at all for the Given Spotify Dataset As there are No Attributes Depecting gender or Metric Measurements So Not Implemented For this Particular DatasetCode Alone
